# %%
print()
print("create connection")
import mysql.connector
mydb = mysql.connector.connect(
       host="localhost",
       user="root",
       passwd=".")
print(mydb)
# Out:
# create connection
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     508             self.sock.settimeout(self._connection_timeout)
# --> 509             self.sock.connect(sockaddr)
#     510         except IOError as err:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-2-f642311f7c86> in <module>
#       5        host="localhost",
#       6        user="root",
# ----> 7        passwd=".")
#       8 print(mydb)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
# ...

# %%
print("hello")
# Out:
# hello

# %%
import mysql.connector

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",user="root",passwd=".")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     508             self.sock.settimeout(self._connection_timeout)
# --> 509             self.sock.connect(sockaddr)
#     510         except IOError as err:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-7-90b1766a05b5> in <module>
#       1 import mysql.connector
# ----> 2 mydb = mysql.connector.connect(host="localhost",user="root",passwd=".")
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
# ...

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",user="root",passwd=".")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     508             self.sock.settimeout(self._connection_timeout)
# --> 509             self.sock.connect(sockaddr)
#     510         except IOError as err:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-13-90b1766a05b5> in <module>
#       1 import mysql.connector
# ----> 2 mydb = mysql.connector.connect(host="localhost",user="root",passwd=".")
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
# ...

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",user="root",passwd=".")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     508             self.sock.settimeout(self._connection_timeout)
# --> 509             self.sock.connect(sockaddr)
#     510         except IOError as err:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-9-90b1766a05b5> in <module>
#       1 import mysql.connector
# ----> 2 mydb = mysql.connector.connect(host="localhost",user="root",passwd=".")
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
# ...

# %%
import mysql.connector

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",user="root",passwd="",database="firstwarehouse")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-97-1dedd46cbd35> in <module>
#       1 import mysql.connector
# ----> 2 mydb = mysql.connector.connect(host="localhost",user="root",passwd="",database="firstwarehouse")
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     177         return CMySQLConnection(*args, **kwargs)
#     178     else:
# --> 179         return MySQLConnection(*args, **kwargs)
#     180 Connect = connect  # pylint: disable=C0103
#     181
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#      93
#      94         if len(kwargs) > 0:
# ---> 95             self.connect(**kwargs)
#      96
#      97     def _do_handshake(self):
#
# ...

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost", user="root", passwd=".")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     508             self.sock.settimeout(self._connection_timeout)
# --> 509             self.sock.connect(sockaddr)
#     510         except IOError as err:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-15-6ea95d7e157c> in <module>
#       1 import mysql.connector
# ----> 2 mydb = mysql.connector.connect(host="localhost", user="root", passwd=".")
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
# ...

# %%
import mysql.connector

# %%
import mysql.connector

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",port="3306" ,user="root", passwd="")
cursor =mydb.cursor()
cursor.execute("show databases")
for x in cursor:
    print(x)
# Out:
# ('contact',)
# ('information_schema',)
# ('mysql',)
# ('orn',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('pythondb',)
# ('shop',)
# ('stal',)
# ('test',)
# ('testdb',)
# ('tourandtravel',)

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",port="3306" ,user="root", passwd="",database="pythondb")
cursor =mydb.cursor()
cursor.execute("show tables")
for x in cursor:
    print(x)
# Out:
# ('customer',)

# %%
import mysql.connector

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",port="3306" ,user="root", passwd="",database="pythondb")
cursor =mydb.cursor()
sql= "insert into customer(cust_name,cust_id) values(%s,%s)"
val=("john","12")

cursor.execute(sql, val)
mydb.commit()
print(cursor.rowcount,"record inserted")
cursor.execute("show tables")
# Out:
# 1 record inserted

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",port="3306" ,user="root", passwd="",database="pythondb")
cursor =mydb.cursor()
sql= "insert into customer(cust_name,cust_id) values(%s,%s)"
val=[
    ("john","12"),
    ("mike","jackson"),
    ("ammy","watson")
    
    
   ]

cursor.executemany(sql, val)
mydb.commit()
print(cursor.rowcount,"record was inserted")
cursor.execute("show tables")
# Out:
# 3 record was inserted

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",port="3306" ,user="root", passwd="",database="pythondb")
cursor =mydb.cursor()
cursor.execute("select * from customer")
myresult = cursor.fetchall()
for x in myresult:
    print(x)
# Out:
# ('john', 12)
# ('john', 12)
# ('mike', 0)
# ('ammy', 0)

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",port="3306",user="root",passwd="",database="pythondb")
cursor =mydb.cursor()
cursor.execute("select cust_name from customer")
myresult = cursor.fetchall()
for x in myresult:
    print(x)
# Out:
# ('john',)
# ('john',)
# ('mike',)
# ('ammy',)

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost", user="root",passwd="",database="pythondb",port="3306")
cursor=mydb.cursor()
sql="select * from customer where cust_name like '%jo%'"
cursor.execute(sql)
myresult = cursor.fetchall()
print(x)
# Out:
# ('ammy',)

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",user="root",passwd="",database="pythondb",port="3306")
cursor= mydb.cursor()
sql= "delete from customer where cust_name='john'"
cursor.execute(sql)
mydb.commit()
print(cursor.rowcount, "record deleted")
# Out:
# 2 record deleted

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",port="3306" ,user="root", passwd="",database="pythondb")
cursor =mydb.cursor()
sql= "insert into customer(cust_name,cust_id) values(%s,%s)"
val=[
    ("john","12"),
    ("mike","jackson"),
    ("ammy","watson"),
    ("scully","watson"),
    ("moulder","ma"),
    ("moulder","ma"),
    ("richard","ug7")
    
    
    
   ]

cursor.executemany(sql, val)
mydb.commit()
print(cursor.rowcount,"record was inserted")
cursor.execute("show tables")
# Out:
# 7 record was inserted

# %%
import mysql.connector
mydb=mysql.connector.connect(host="localhost",port="3306",user="root",passwd="",database="orn")
cursor=mydb.cursor()
sql="drop table if exists rdn"
cursor.execute(sql)

# %%
import mysql.connector
mydb=mysql.onnector.connect(host="localhost",port="3306",user="root",passwd="",database="pythondb")
cursor=mydb.cursor()
sql= "select \  "
                           '')
# Out:
#   File "<ipython-input-1-b4d4a09e10d7>", line 5
#     '')
#     ^
# IndentationError: unexpected indent

# %%
import mysql.connector
mydb=mysql.connector.connect(host="localhost",user="root",passwd="",port="3306",database="pythondb")
cursor=mydb.cursor()
sql= "update customer set cust_name='dina' where cust_name='john'"

cursor.execute(sql)
mydb.commit()
print(cursor.rowcount, "record affected")
# Out:
# 5 record affected

# %%
import mysql.connector
mydb=mysql.connector.connect(host="localhost",user="root",passwd="",database="pythondb")
cursor=mydb.cursor()
sql="update customer set cust_id=%s wherecust_id=%s"
val=("0","01")
mydb.commit()
print(cursor.rowcount,"record affected")
# Out:
# -1 record affected

# %%
import mysql.connector
mydb=mysql.connector.connect(host="localhost",user="root",passwd="",database="pythondb",port="3306")
cursor=mydb.cursor()
sql="select  user.name as userr,  product.name as fav  from user inner join product on user.fav=product.id"
cursor.execute(sql)
myresult = cursor.fetchall()
for x in myresult:
    print(x)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-19-7e8b9ac9fe2d> in <module>
#       3 cursor=mydb.cursor()
#       4 sql="select  user.name as userr,  product.name as fav  from user inner join product on user.fav=product.id"
# ----> 5 cursor.execute(sql)
#       6 myresult = cursor.fetchall()
#       7 for x in myresult:
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     549         else:
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#     553                 if self._connection._have_next_result:  # pylint: disable=W0212
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
# ...

# %%
import mysql.connector
mydb=mysql.connector.connect(host="localhost",user="root",passwd="",database="pythondb",port="3306")
cursor=mydb.cursor()
sql="select  users.name as user,  product.name as favorite  from users  inner join product on users.fav=product.id"
cursor.execute(sql)
myresult = cursor.fetchall()
for x in myresult:
    print(x)

# %%
import mysql.connector
mydb=mysql.connector.connect(host="localhost",user="root",passwd="",database="pythondb",port="3306")
cursor=mydb.cursor()
sql="select  users.name as user,  product.name as favorite  from users  left join product on users.fav=product.id"
cursor.execute(sql)
myresult = cursor.fetchall()
for x in myresult:
    print(x)
# Out:
# ('john', None)
# ('peter', None)
# ('peter', None)
# ('amy', None)
# ('hannah', None)

# %%
import mysql.connector
mydb=mysql.connector.connect(host="localhost",user="root",passwd="",database="pythondb",port="3306")
cursor=mydb.cursor()
sql="select  users.name as user,  product.name as favorite  from users  right join product on users.fav=product.id"
cursor.execute(sql)
myresult = cursor.fetchall()
for x in myresult:
    print(x)
# Out:
# (None, 'shoes')
# (None, 'shirt')
# (None, 'chocolate')
# (None, 'tasty lemons')
# (None, 'vanilla dreams')

# %%
import re
txt="the rain in spain"
x= re.search("^the.*spain$",txt)
if(x):
    print("yes,we have a match")
else:
    print("no match")
# Out:
# yes,we have a match

# %%
import re
txt="the rain in spain cat all"
x=re.findall("ai",txt)
print(x)
# Out:
# ['ai', 'ai']

# %%
import re

txt = "The rain in Spain"
x = re.search("\s", txt)

print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3

# %%
import re
txt="the rain in spain"
x=re.search("\",txt)
print("the first white-space character is located in position:", x.start())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-e880818b165d> in <module>
#       2 txt="the rain in spain"
#       3 x=re.search("\b",txt)
# ----> 4 print("the first white-space character is located in position:", x.start())
#
# AttributeError: 'NoneType' object has no attribute 'start'

# %%
try:
  print(x)
except:
  print("An exception occurred")
# Out:
# An exception occurred

# %%
try:
  print(x)
except NameError:
  print("Variable x is not defined")
except:
  print("Something else went wrong")
# Out:
# Variable x is not defined

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
try:
  print(x)
except:
  print("Something went wrong")
finally:
  print("The 'try except' is finished")
# Out:
# Something went wrong
# The 'try except' is finished

# %%
username = input("Enter username:")
print("Username is: " + username)
# Out:
# Enter username:nisha
# Username is: nisha

# %%
username = raw_input("Enter username:")
print("Username is: " + username)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-748e799f9fc2> in <module>
# ----> 1 username = raw_input("Enter username:")
#       2 print("Username is: " + username)
#
# NameError: name 'raw_input' is not defined

# %%
price = 49
txt = "The price is {} dollars"
print(txt.format(price))
# Out:
# The price is 49 dollars

# %%
price = 49
txt = "The price is {:.2f} dollars"
print(txt.format(price))
# Out:
# The price is 49.00 dollars

# %%
quantity=3
itemno=567
price=49
myorder="i want {} pieces of item of item no  {} for {:.2f} dollers."
print(myorder.format(quantity,itemno,price))
# Out:
# i want 3 pieces of item of item no  567 for 49.00 dollers.

# %%
quantity = 3
itemno = 567
price = 49
myorder = "I want {} pieces of item number {} for {:.2f} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item number 567 for 49.00 dollars.

# %%
quantity = 3
itemno = 567
price = 49
myorder = "I want {0} pieces of item number {1} for {2:.2f} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item number 567 for 49.00 dollars.

# %%
age = 36
name = "John"
txt = "His name is {1}. {1} is {0} years old."
print(txt.format(age, name))
# Out:
# His name is John. John is 36 years old.

# %%
age=36
name="john"
txt="his name is {1}. {1} is {0} year old"
print(txt.format(age,name))
# Out:
# his name is john. john is 36 year old

# %%
myorder="i have a {name} it is a model{}."
print(myorder.format(name="ford", model="mustang"))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-7430671d20f7> in <module>
#       1 myorder="i have a {name} it is a model{}."
# ----> 2 print(myorder.format(name="ford", model="mustang"))
#
# IndexError: tuple index out of range

# %%
f=open("mydemo.txt" ,"r")
print (f.read())
# Out:
# this is python programming language .

# %%
f=open("mydemo.txt","r")
print(f.read(4))
# Out:
# this

# %%
f=open("mydemo.txt","r")
print(f.readline())
# Out:
# this is python programming language .

# %%
f=open("mydemo.txt","r")
print(f.readline())
print(f.readline())
print(f.readline())
# Out:
# this is python programming language .

# %%
f=open("mydemo.txt","r")
for x in f:
    print(x)
# Out:
# Hello! Welcome to mydemo.txt
#
# This file is for testing purposes.
#
# Good Luck!

# %%
f=open("mydemo.txt","r")
print(f.readline())
f.close()

# %%
f=open("mydemo.txt","a")
f.write("now this file has more content")
f.close()
f=open("mydemo.txt","r")
print(f.read())
# Out:
# Hello! Welcome to mydemo.txt
# This file is for testing purposes.
# Good Luck!now this file has more contentnow this file has more content

# %%
f=open("mydemo.txt","w")
f.write("Woops! i have deleted my content")
f.close()
f=open("mydemo.txt","r")
print(f.read())
# Out:
# Woops! i have deleted my content

# %%
f=open("myfile.txt","x")

# %%
f=open("myfile.txt","w")

# %%
import os
os.remove("mydemo.txt")

# %%
f=close("myfile.txt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-50f20226ac73> in <module>
# ----> 1 f=close("myfile.txt")
#
# NameError: name 'close' is not defined

# %%
import numpy
arr= numpy.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
import numpy 
print(numpy.__version__)
# Out:
# 1.18.1

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(arr)

print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
import numpy as np

arr = np.array(42)

print(arr)
# Out:
# 42

# %%
import numpy as np

arr = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])

print(arr)
# Out:
# [[[1 2 3]
#   [4 5 6]]
#
#  [[1 2 3]
#   [4 5 6]]]

# %%
import numpy as np
import cv2
img=cv2.imread('po.jpg',0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-9d51b4deae42> in <module>
#       1 import numpy as np
# ----> 2 import cv2
#       3 img=cv2.imread('po.jpg',0)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import cv2

# %%
import numpy as np
import cv2
img=cv2.imread('po.jpg',0)

# %%
cv2.imshow('image',img)
cv2.waitkey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-349ecc290e8e> in <module>
# ----> 1 cv2.imshow('image',img)
#       2 cv2.waitkey(0)
#       3 cv2.destroyAllWindows()
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\highgui\src\window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
image=cv2.imread('po.jpg')
print(image.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-52ed04bb2aae> in <module>
#       1 image=cv2.imread('po.jpg')
# ----> 2 print(image.shape)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
import numpy as np
import cv2
img=cv2.imread('po.jpg',0)
cv2.imshow('image',img)
cv2.waitkey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-36-9896128d2264> in <module>
#       2 import cv2
#       3 img=cv2.imread('po.jpg',0)
# ----> 4 cv2.imshow('image',img)
#       5 cv2.waitkey(0)
#       6 cv2.destroyAllWindows()
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\highgui\src\window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
import numpy as np
import cv2
img=cv2.imread('1n.jpg')
red = img[100,100,0]
print (red)
blue=img[100,100,0]
print (blue)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-1623956e5ee8> in <module>
#       2 import cv2
#       3 img=cv2.imread('1n.jpg')
# ----> 4 red = img[100,100,0]
#       5 print (red)
#       6 blue=img[100,100,0]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
img.item(10,10,2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-164c46b2f4be> in <module>
# ----> 1 img.item(10,10,2)
#
# AttributeError: 'NoneType' object has no attribute 'item'

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2
img=cv2.imread('1n.jpg',0)
cv2.imshow('image',img)
k=cv2.waitkey(0) & 0xFF
if k==27:
    cv2.destroyAllWindows()
elif k==ord('s'):
    cv2.imwrite('po.jpg',img)
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-a7f6cc9f6540> in <module>
#       3 import cv2
#       4 img=cv2.imread('1n.jpg',0)
# ----> 5 cv2.imshow('image',img)
#       6 k=cv2.waitkey(0) & 0xFF
#       7 if k==27:
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\highgui\src\window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
import numpy as np 
import cv2
img = cv2.imread('one.jpg')
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np 
import cv2
img = cv2.imread('one.jpg')
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np 
import cv2
img = cv2.imread('two.jpg')
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np 
import cv2
img = cv2.imread('three.jpg')
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np 
import cv2
img = cv2.imread('three.jpg')
px=img[100,100]
print(px) 
blue = img[100,100,0]
print (blue)
# Out:
# [216 217 227]
# 216

# %%
import numpy as np 
import cv2
img = cv2.imread('three.jpg')
img.item(10,10,2)
# Out:
# 66

# %%
import numpy as np 
import cv2
img = cv2.imread('three.jpg')
img.itemset((10,10,2),100)
img.item(10,10,2)
# Out:
# 100

# %%
import numpy as np 
import cv2
img = cv2.imread('three.jpg')
print (img.shape)
# Out:
# (337, 600, 3)

# %%
import numpy as np
import cv2
img=cv2.imread('three.jpg')
print (img.size)
# Out:
# 606600

# %%
import numpy as np 
import cv2
img = cv2.imread('three.jpg')
print(img.dtype)
# Out:
# uint8

# %%
import numpy as np 
import cv2
img = cv2.imread('three.jpg')
ball = img[280:340,330:390]
img[273:333,100:160]=ball
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-543822361084> in <module>
#       3 img = cv2.imread('three.jpg')
#       4 ball = img[280:340,330:390]
# ----> 5 img[273:333,100:160]=ball
#
# ValueError: could not broadcast input array from shape (57,60,3) into shape (60,60,3)

# %%
import numpy as np 
import cv2
img = cv2.imread('three.jpg')
b,g,r = cv2.split(img)
img = cv2.merge((b,g,r))

# %%
import cv2
import numpy as np
from matplotlib import pylot as plt
BLUE = [255,255,0]
img1= cv2.imread('opencv_three.jpg')
replicate = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REPLICATE)
reec  2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT)
reflect101=cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT_101)
wrap=cv2.copyMakeBorder(img,10,10,10,10,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)
plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGIAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'grey'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.sublot(236),plt.imshow(constant,'gray',plt.title('CONSTANT')

plt.show()
# Out:
#   File "<ipython-input-33-e6e3ce3b0f09>", line 18
#     plt.show()
#       ^
# SyntaxError: invalid syntax

# %%
x=np.uint8([250])
y=np.uint8([10])
print (cv2.add(x,y))
print(x+y)
# Out:
# [[255]]
# [4]

# %%
img1= cv2.imread('three.jpg')
img2=cv2.imread('four.jpg')
dst=cv2.addWeighted(img1,0.7,img2,0.3,0)
cv2.imshow('dst',dst)
cv2.waitKey(0)
cv2.destroyallWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-47-f01e2241ac0d> in <module>
#       1 img1= cv2.imread('three.jpg')
#       2 img2=cv2.imread('four.jpg')
# ----> 3 dst=cv2.addWeighted(img1,0.7,img2,0.3,0)
#       4 cv2.imshow('dst',dst)
#       5 cv2.waitKey(0)
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\core\src\arithm.cpp:669: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
img1= cv2.imread('three.jpg')
img2=cv2.imread('four.jpg')
dst=cv2.addWeighted(img1,0.7,img2,0.3,0)
cv2.imshow('dst',dst)
cv2.waitKey(0)
cv2.destroyallWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-f01e2241ac0d> in <module>
#       4 cv2.imshow('dst',dst)
#       5 cv2.waitKey(0)
# ----> 6 cv2.destroyallWindows()
#
# AttributeError: module 'cv2.cv2' has no attribute 'destroyallWindows'

# %%
from skimage.exposure import rescale_intensity
import numpy as np
import argparse
import cv2

# %%
def convolve(image, kernel):
    (iH, iW) = image.shape[:2]
(kH, kW) = kernel.shape[:2]
    pad = (kW - 1) // 2
    image = cv2.copyMakeBorder(image, pad, pad, pad, pad,
      cv2.BORDER_REPLICATE)
    output = np.zeros((iH, iW), dtype="float32")
# Out:
#   File "<ipython-input-5-6a61af2a3843>", line 4
#     pad = (kW - 1) // 2
#     ^
# IndentationError: unexpected indent

# %%
def convolve(image, kernel):
	# grab the spatial dimensions of the image, along with
	# the spatial dimensions of the kernel
	(iH, iW) = image.shape[:2]
	(kH, kW) = kernel.shape[:2]
	# allocate memory for the output image, taking care to
	# "pad" the borders of the input image so the spatial
	# size (i.e., width and height) are not reduced
	pad = (kW - 1) // 2
	image = cv2.copyMakeBorder(image, pad, pad, pad, pad,
		cv2.BORDER_REPLICATE)
	output = np.zeros((iH, iW), dtype="float32")

# %%
# loop over the input image, "sliding" the kernel across
	# each (x, y)-coordinate from left-to-right and top to
	# bottom
	for y in np.arange(pad, iH + pad):
		for x in np.arange(pad, iW + pad):
			# extract the ROI of the image by extracting the
			# *center* region of the current (x, y)-coordinates
			# dimensions
			roi = image[y - pad:y + pad + 1, x - pad:x + pad + 1]
			# perform the actual convolution by taking the
			# element-wise multiplicate between the ROI and
			# the kernel, then summing the matrix
			k = (roi * kernel).sum()
			# store the convolved value in the output (x,y)-
			# coordinate of the output image
			output[y - pad, x - pad] = k
# Out:
#   File "<ipython-input-7-ae4a5f466198>", line 4
#     for y in np.arange(pad, iH + pad):
#     ^
# IndentationError: unexpected indent

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
# let img1 be an image with no features 
img1 = np.array([np.array([200, 200]), np.array([200, 200])]) 
img2 = np.array([np.array([200, 200]), np.array([0, 0])]) 
img3 = np.array([np.array([200, 0]), np.array([200, 0])]) 
  
kernel_horizontal = np.array([np.array([2, 2]), np.array([-2, -2])]) 
print(kernel_horizontal, 'is a kernel for detecting horizontal edges') 
  
kernel_vertical = np.array([np.array([2, -2]), np.array([2, -2])]) 
print(kernel_vertical, 'is a kernel for detecting vertical edges') 
  
# We will apply the kernels on the images by 
# elementwise multiplication followed by summation 
def apply_kernel(img, kernel): 
    return np.sum(np.multiply(img, kernel)) 
  
# Visualizing img1 
plt.imshow(img1) 
plt.axis('off') 
plt.title('img1') 
plt.show() 
  
# Checking for horizontal and vertical features in image1 
print('Horizontal edge confidence score:', apply_kernel(img1,  
                                            kernel_horizontal)) 
print('Vertical edge confidence score:', apply_kernel(img1,  
                                            kernel_vertical)) 
  
# Visualizing img2 
plt.imshow(img2) 
plt.axis('off') 
plt.title('img2') 
plt.show() 
  
# Checking for horizontal and vertical features in image2 
print('Horizontal edge confidence score:', apply_kernel(img2,  
                                            kernel_horizontal)) 
print('Vertical edge confidence score:', apply_kernel(img2,  
                                            kernel_vertical)) 
  
# Visualizing img3 
plt.imshow(img3) 
plt.axis('off') 
plt.title('img3') 
plt.show() 
  
# Checking for horizontal and vertical features in image3 
print('Horizontal edge confidence score:', apply_kernel(img3,  
                                            kernel_horizontal)) 
print('Vertical edge confidence score:', apply_kernel(img3,  
                                            kernel_vertical))
# Out:
# [[ 2  2]
#  [-2 -2]] is a kernel for detecting horizontal edges
# [[ 2 -2]
#  [ 2 -2]] is a kernel for detecting vertical edges
# Horizontal edge confidence score: 0
# Vertical edge confidence score: 0
# Horizontal edge confidence score: 800
# Vertical edge confidence score: 0
# Horizontal edge confidence score: 0
# Vertical edge confidence score: 800

# %%
import cv2
def load_image(image_path):
    """
    Load the image using opencv
    :param image_path: <String> Path of input_image
    """
    coloured_image = cv2.imread(image_path)
    grey_image = cv2.cvtColor(coloured_image, cv2.COLOR_BGR2GRAY)
    print('image matrix size: ', grey_image.shape)
    print('\n First 5 columns and rows of the image matrix: \n', grey_image[:5, :5])
    cv2.imwrite('TopLeft5x5.jpg', grey_image[:5, :5])
    return grey_image

input_image = load_image('four.jpg')
# Out:
# image matrix size:  (337, 600)
#
#  First 5 columns and rows of the image matrix:
#  [[ 42  40  34  44  78]
#  [ 42  40  35  46  82]
#  [ 42  40  37  49  88]
#  [ 42  40  39  53  96]
#  [ 43  40  41  57 103]]

# %%
def convolve2d(image, kernel):
    """
    This function which takes an image and a kernel and returns the convolution of them.

    :param image: a numpy array of size [image_height, image_width].
    :param kernel: a numpy array of size [kernel_height, kernel_width].
    :return: a numpy array of size [image_height, image_width] (convolution output).
    """
    # Flip the kernel
    kernel = np.flipud(np.fliplr(kernel))
    # convolution output
    output = np.zeros_like(image)

    # Add zero padding to the input image
    image_padded = np.zeros((image.shape[0] + 2, image.shape[1] + 2))
    image_padded[1:-1, 1:-1] = image

    # Loop over every pixel of the image
    for x in range(image.shape[1]):
        for y in range(image.shape[0]):
            # element-wise multiplication of the kernel and the image
            output[y, x]=(kernel * image_padded[y: y+3, x: x+3]).sum()

    return output

# kernel to be used to get sharpened image
KERNEL = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
image_sharpen = convolve2d(input_image, kernel=KERNEL)
cv2.imwrite('sharpened_image.jpg', image_sharpen)
# Out:
# True

# %%
def convolve2d(image, kernel):
    """
    This function which takes an image and a kernel and returns the convolution of them.

    :param image: a numpy array of size [image_height, image_width].
    :param kernel: a numpy array of size [kernel_height, kernel_width].
    :return: a numpy array of size [image_height, image_width] (convolution output).
    """
    # Flip the kernel
    kernel = np.flipud(np.fliplr(kernel))
    # convolution output
    output = np.zeros_like(image)

    # Add zero padding to the input image
    image_padded = np.zeros((image.shape[0] + 2, image.shape[1] + 2))
    image_padded[1:-1, 1:-1] = image

    # Loop over every pixel of the image
    for x in range(image.shape[1]):
        for y in range(image.shape[0]):
            # element-wise multiplication of the kernel and the image
            output[y, x]=(kernel * image_padded[y: y+3, x: x+3]).sum()

    return output
# kernel to be used for edge detection
image_edge1 = convolve2d(input_image,
                         kernel=np.array([[-1, -1, -1], [-1, 4, -1],[-1, -1, -1]]))
cv2.imwrite('two.jpg', image_edge1)

image_edge2 = convolve2d(input_image,
                         kernel=np.array([[-1, 0, 1], [0, 0, 0], [1, 0, -1]]))
cv2.imwrite('one.jpg', image_edge2)
# Out:
# True

# %%
def convolve2d(image, kernel):
    """
    This function which takes an image and a kernel and returns the convolution of them.

    :param image: a numpy array of size [image_height, image_width].
    :param kernel: a numpy array of size [kernel_height, kernel_width].
    :return: a numpy array of size [image_height, image_width] (convolution output).
    """
    # Flip the kernel
    kernel = np.flipud(np.fliplr(kernel))
    # convolution output
    output = np.zeros_like(image)

    # Add zero padding to the input image
    image_padded = np.zeros((image.shape[0] + 2, image.shape[1] + 2))
    image_padded[1:-1, 1:-1] = image

    # Loop over every pixel of the image
    for x in range(image.shape[1]):
        for y in range(image.shape[0]):
            # element-wise multiplication of the kernel and the image
            output[y, x]=(kernel * image_padded[y: y+3, x: x+3]).sum()

    return output
#kernel to be used for box blur
imageboxblur = convolve2d(input_image,
                         kernel=np.array([[1, 1, 1], [1, 1, 1], [1, 1, 1]])/9.0)
cv2.imwrite('five.jpg', imageboxblur)

# kernel to be used for gaussian blur
imagegaussianblur = convolve2d(input_image,
                         kernel=np.array([[1, 2, 1], [2, 4, 2], [1, 2, 1]])/16.0)
cv2.imwrite('six.jpg', imagegaussianblur)
# Out:
# True

# %%
>>> a = np.array([[1, 2, 0, 0],
       [5, 3, 0, 4],
       [0, 0, 0, 7],
      [9, 3, 0, 0]])
    k = np.array([[1,1,1],[1,1,0],[1,0,0]])
      from scipy import ndimage
ndimage.convolve(a, k, mode='constant', cval=0.0)
array([[11, 10,  7,  4],
       [10,  3, 11, 11],
       [15, 12, 14,  7],
       [12,  3,  7,  0]])
# Out:
#   File "<ipython-input-27-28ed969be18e>", line 5
#     k = np.array([[1,1,1],[1,1,0],[1,0,0]])
#     ^
# IndentationError: unexpected indent

# %%
>>> a = np.array([[1, 2, 0, 0]])
>>> k = np.array([[1,1,1],[1,1,0],[1,0,0]])
>>> from scipy import ndimage
>>> ndimage.convolve(a, k, mode='constant', cval=0.0)
array([[11, 10,  7,  4],
       [10,  3, 11, 11],
       [15, 12, 14,  7],
       [12,  3,  7,  0]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-e308378b5b9d> in <module>
#       3 from scipy import ndimage
#       4 ndimage.convolve(a, k, mode='constant', cval=0.0)
# ----> 5 array([[11, 10,  7,  4],
#       6        [10,  3, 11, 11],
#       7        [15, 12, 14,  7],
#
# NameError: name 'array' is not defined

# %%
import scipy
import scipy.misc
from scipy import ndimage

im = scipy.misc.imread('two.jpg')
processed = ndimage.sobel(im, 0)
scipy.misc.imsave('sobel.jpg', processed)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-1026460fb8ff> in <module>
#       3 from scipy import ndimage
#       4
# ----> 5 im = scipy.misc.imread('two.jpg')
#       6 processed = ndimage.sobel(im, 0)
#       7 scipy.misc.imsave('sobel.jpg', processed)
#
# AttributeError: module 'scipy.misc' has no attribute 'imread'

# %%
import scipy
from scipy import ndimage

im = scipy.misc.imread('three.jpg')
processed = ndimage.sobel(im, 0)
scipy.misc.imsave('sobel.jpg', processed)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-b74daa2ac0ea> in <module>
#       2 from scipy import ndimage
#       3
# ----> 4 im = scipy.misc.imread('three.jpg')
#       5 processed = ndimage.sobel(im, 0)
#       6 scipy.misc.imsave('sobel.jpg', processed)
#
# AttributeError: module 'scipy' has no attribute 'misc'

# %%
import numpy as np
from PIL import Image, ImageDraw
import scipy.misc



from scipy import ndimage

im = scipy.misc.imread('three.jpg')
im = im.astype('int32')
dx = ndimage.sobel(im, 0)  # horizontal derivative
dy = ndimage.sobel(im, 1)  # vertical derivative
mag = numpy.hypot(dx, dy)  # magnitude
mag *= 255.0 / numpy.max(mag)  # normalize (Q&D)
scipy.misc.imsave('sobel.jpg', mag)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-95f870db441a> in <module>
#       1 import numpy as np
# ----> 2 from PIL import Image, ImageDraw
#       3 import scipy.misc
#       4
#       5
#
# ModuleNotFoundError: No module named 'PIL'

# %%
 import scipy.misc

scipy.misc.imread
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-061f1df7c7c4> in <module>
#       1 import scipy.misc
#       2
# ----> 3 scipy.misc.imread
#
# AttributeError: module 'scipy.misc' has no attribute 'imread'

# %%
import numpy
import scipy
from scipy import ndimage

im = scipy.misc.imread('bike.jpg')
im = im.astype('int32')
dx = ndimage.sobel(im, 0)  # horizontal derivative
dy = ndimage.sobel(im, 1)  # vertical derivative
mag = numpy.hypot(dx, dy)  # magnitude
mag *= 255.0 / numpy.max(mag)  # normalize (Q&D)
scipy.misc.imsave('sobel.jpg', mag)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-d5a9767dc451> in <module>
#       3 from scipy import ndimage
#       4
# ----> 5 im = scipy.misc.imread('bike.jpg')
#       6 im = im.astype('int32')
#       7 dx = ndimage.sobel(im, 0)  # horizontal derivative
#
# AttributeError: module 'scipy.misc' has no attribute 'imread'

# %%
>>> import numpy as np
>>> from PIL import Image, ImageDraw
>>> import scipy.misc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-8ed7a6a434eb> in <module>
#       1 import numpy as np
# ----> 2 from PIL import Image, ImageDraw
#       3 import scipy.misc
#
# ModuleNotFoundError: No module named 'PIL'

# %%
import numpy as np
import cv2
import argparse
import matplotlib.pyplot as plt
from Computer_Vision.Sobel_Edge_Detection.convolution import convolution
from Computer_Vision.Sobel_Edge_Detection.gaussian_smoothing import gaussian_blur
 
 
def sobel_edge_detection(image, filter, verbose=False):
    new_image_x = convolution(image, filter, verbose)
 
    if verbose:
        plt.imshow(new_image_x, cmap='gray')
        plt.title("Horizontal Edge")
        plt.show()
 
    new_image_y = convolution(image, np.flip(filter.T, axis=0), verbose)
 
    if verbose:
        plt.imshow(new_image_y, cmap='gray')
        plt.title("Vertical Edge")
        plt.show()
 
    gradient_magnitude = np.sqrt(np.square(new_image_x) + np.square(new_image_y))
 
    gradient_magnitude *= 255.0 / gradient_magnitude.max()
 
    if verbose:
        plt.imshow(gradient_magnitude, cmap='gray')
        plt.title("Gradient Magnitude")
        plt.show()
 
    return gradient_magnitude
 
 
if __name__ == '__main__':
    filter = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
 
    ap = argparse.ArgumentParser()
    ap.add_argument("-i", "--image", required=True, help="Path to the image")
    args = vars(ap.parse_args())
 
    image = cv2.imread(args["image"])
    image = gaussian_blur(image, 9, verbose=True)
    sobel_edge_detection(image, filter, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-22ea2137337a> in <module>
#       3 import argparse
#       4 import matplotlib.pyplot as plt
# ----> 5 from Computer_Vision.Sobel_Edge_Detection.convolution import convolution
#       6 from Computer_Vision.Sobel_Edge_Detection.gaussian_smoothing import gaussian_blur
#       7
#
# ModuleNotFoundError: No module named 'Computer_Vision'

# %%
import scipy
scipy.misc.imsave(slice,dat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-ac833eebd72a> in <module>
#       1 import scipy
# ----> 2 scipy.misc.imsave(slice,dat)
#
# AttributeError: module 'scipy.misc' has no attribute 'imsave'

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
# let img1 be an image with no features 
img1 = np.array([np.array([200, 200]), np.array([200, 200])]) 
img2 = np.array([np.array([200, 200]), np.array([0, 0])]) 
img3 = np.array([np.array([200, 0]), np.array([200, 0])]) 
  
kernel_horizontal = np.array([np.array([2, 2]), np.array([-2, -2])]) 
print(kernel_horizontal, 'is a kernel for detecting horizontal edges') 
  
kernel_vertical = np.array([np.array([2, -2]), np.array([2, -2])]) 
print(kernel_vertical, 'is a kernel for detecting vertical edges') 
  
# We will apply the kernels on the images by 
# elementwise multiplication followed by summation 
def apply_kernel(img, kernel): 
    return np.sum(np.multiply(img, kernel)) 
  
# Visualizing img1 
plt.imshow(img1) 
plt.axis('off') 
plt.title('img1') 
plt.show() 
  
# Checking for horizontal and vertical features in image1 
print('Horizontal edge confidence score:', apply_kernel(img1,  
                                            kernel_horizontal)) 
print('Vertical edge confidence score:', apply_kernel(img1,  
                                            kernel_vertical)) 
  
# Visualizing img2 
plt.imshow(img2) 
plt.axis('off') 
plt.title('img2') 
plt.show() 
  
# Checking for horizontal and vertical features in image2 
print('Horizontal edge confidence score:', apply_kernel(img2,  
                                            kernel_horizontal)) 
print('Vertical edge confidence score:', apply_kernel(img2,  
                                            kernel_vertical)) 
  
# Visualizing img3 
plt.imshow(img3) 
plt.axis('off') 
plt.title('img3') 
plt.show() 
  
# Checking for horizontal and vertical features in image3 
print('Horizontal edge confidence score:', apply_kernel(img3,  
                                            kernel_horizontal)) 
print('Vertical edge confidence score:', apply_kernel(img3,  
                                            kernel_vertical))

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('opencv_logo.png')

kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('opencv_logo.png')

blur = cv2.blur(img,(5,5))

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('opencv_logo.png')

blur = cv2.blur(img,(5,5),0)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('opencv_logo.png')
median = cv2.medianBlur(img,5)


plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np

img = cv2.imread('sobel.jpg',0)
kernel = np.ones((5,5),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('dave.jpg',0)


sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])


plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
  from skimage.exposure import rescale_intensity

     
import numpy as np
import argparse
import cv2
def convolve(image,kernel):
    (iH,iW)=image.shape[:2]
    pad=(kW-1) //2
    image=cv2.copyMakeBorder(image,pad
                             ,pad,pad,pad,
                              cv2.BORDER_REPLICATE)
    output=np.zeros((iH,iW))
    for y in np.arange(pad,iH+pad):
        for x in np.arange(pad,iW+pad):
            roi=image[y-pad:y+pad+1,x-pad:x+pad+1]
            k=(roi*kernel).sum()
            output[y-pad,x-pad]=k
            output=rescale_intensity(output,in_range=(0,255))
            output=(output*255).astype("uint8")
            return output
        ap= argparse.ArgumentParser()
        ap.add_argument("-i","--image",required=True,help="path to the input image")
        args=vars(ap.parse_args())
        smallBlur=np.ones((7,7) , dtype="float")*(1.0/(7*7))
        largeBlur=np.one((21,21) , dtype="float")*(1.0 /(21*21))
        sharpen=np.array(([0, -1, 0],
                         [-1, 5,-1],
                         [0,-1,0]), dtype="int")
        laplacian=np.array(([-1,0,1],
                           [1,-4,1],
                           [0,1,0]), dtype="int")
        sobelX=np.array(([-1,0,1],
                         [-2,0.,2],
                         [-1,0,1]),dtype="int")
        sobelY=np.array(([-1,-2,-1],
                         [0,0,0], 
kernelBank = (
    ("small_blur", smallBlur),
	("large_blur", largeBlur),
	("sharpen", sharpen),
	("laplacian", laplacian),
	("sobel_x", sobelX),
	("sobel_y", sobelY)
)
image=cv2.imread(args["image"])
gray=cv2.cvtolor(image,cv2.COLOR_BGR2GRAY)
for(kernelName,kernel) in kernelBank:
                      print("[INFO] applying  {} kernel".format(kernelName))
                      convelOutput=convole(gray,kernel)
                      opencvOutput=cv.fiilter2D(gray,-1,kernel)

                      cv2.imshow("original",gray)
                      cv2.imshow("{} - convole".format(kernelName),convoleOutput)
                      cv2.imshow("{} - opencv".format (kernalName), opencvOutput)                

                                      
                      cv2.waitkey(0)
                      cv2.destroyAllWindows()
# Out:
#   File "<ipython-input-2-a879b4b19ebe>", line 38
#     kernelBank = (
#                ^
# SyntaxError: invalid syntax

# %%
from skimage.exposure import rescale_intensity
import numpy as np
import argparse
import cv2
def convolve(image, kernel):

	(iH, iW) = image.shape[:2]
	(kH, kW) = kernel.shape[:2]


	pad = (kW - 1) // 2
	image = cv2.copyMakeBorder(image, pad, pad, pad, pad,
		cv2.BORDER_REPLICATE)
	output = np.zeros((iH, iW), dtype="float")
   
	for y in np.arange(pad, iH + pad):
		for x in np.arange(pad, iW + pad):

			roi = image[y - pad:y + pad + 1, x - pad:x + pad + 1]

			k = (roi * kernel).sum()

			output[y - pad, x - pad] = k
            
	output = rescale_intensity(output, in_range=(0, 255))
	output = (output * 255).astype("uint8")

	return output

ap = argparse.ArgumentParser()
ap.add_argument("-i", "--image", required=True,
	help="path to the input image")
args = vars(ap.parse_args())

smallBlur = np.ones((7, 7), dtype="float") * (1.0 / (7 * 7))
largeBlur = np.ones((21, 21), dtype="float") * (1.0 / (21 * 21))

sharpen = np.array((
	[0, -1, 0],
	[-1, 5, -1],
	[0, -1, 0]), dtype="int")

laplacian = np.array((
	[0, 1, 0],
	[1, -4, 1],
	[0, 1, 0]), dtype="int")
# construct the Sobel x-axis kernel
sobelX = np.array((
	[-1, 0, 1],
	[-2, 0, 2],
	[-1, 0, 1]), dtype="int")
# construct the Sobel y-axis kernel
sobelY = np.array((
	[-1, -2, -1],
	[0, 0, 0],
	[1, 2, 1]), dtype="int")

# load the input image and convert it to grayscale
image = cv2.imread(args["image"])
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# loop over the kernels
for (kernelName, kernel) in kernelBank:

	print("[INFO] applying {} kernel".format(kernelName))
	convoleOutput = convolve(gray, kernel)
	opencvOutput = cv2.filter2D(gray, -1, kernel)
	# show the output images
	cv2.imshow("original", gray)
	cv2.imshow("{} - convole".format(kernelName), convoleOutput)
	cv2.imshow("{} - opencv".format(kernelName), opencvOutput)
	cv2.waitKey(0)
	cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img = cv2.imread('messi5.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gaussian = cv2.GaussianBlur(gray,(3,3),0)

#canny
img_canny = cv2.Canny(img,100,200)

#sobel
img_sobelx = cv2.Sobel(img_gaussian,cv2.CV_8U,1,0,ksize=5)
img_sobely = cv2.Sobel(img_gaussian,cv2.CV_8U,0,1,ksize=5)
img_sobel = img_sobelx + img_sobely


#prewitt
kernelx = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
kernely = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
img_prewittx = cv2.filter2D(img_gaussian, -1, kernelx)
img_prewitty = cv2.filter2D(img_gaussian, -1, kernely)


cv2.imshow("Original Image", img)
cv2.imshow("Canny", img_canny)
cv2.imshow("Sobel X", img_sobelx)
cv2.imshow("Sobel Y", img_sobely)
cv2.imshow("Sobel", img_sobel)
cv2.imshow("Prewitt X", img_prewittx)
cv2.imshow("Prewitt Y", img_prewitty)
cv2.imshow("Prewitt", img_prewittx + img_prewitty)


cv2.waitKey(0)
cv2.destroyAllWindows()
